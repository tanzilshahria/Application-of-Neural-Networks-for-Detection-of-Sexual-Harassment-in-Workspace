# %%
import tensorflow as tf
import os
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

if not os.path.isdir('models'):
    os.mkdir('models')
    
print('TensorFlow version:', tf.__version__)
print('Is using GPU?', tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.3.0
# WARNING:tensorflow:From <ipython-input-1-baeee846c934>:12: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Is using GPU? True

# %%
import cv2
import keras
from keras.models import Sequential
from keras.layers import Dense, InputLayer, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('Data/train_new.csv')
train.head()
# Out:
#                             image  class
# 0  Harassment_h36.mp4_frame34.jpg      1
# 1      Normal_n27.mp4_frame20.jpg      0
# 2      Normal_n46.mp4_frame43.jpg      0
# 3    Harassment_h3.mp4_frame6.jpg      1
# 4  Harassment_h15.mp4_frame10.jpg      1

# %%
# creating an empty list
train_image = []

# for loop to read and store frames
for i in tqdm(range(train.shape[0])):
    # loading the image and keeping the target size as (224,224,3)
    img = image.load_img('train/'+train['image'][i], target_size=(224,224,3))
    # converting it to array
    img = image.img_to_array(img)
    # normalizing the pixel value
    img = img/255.0
    # appending the image to the train_image list
    train_image.append(img)
    
# converting the list to numpy array
X = np.array(train_image)

# shape of the array
X.shape
# Out:
# 100%|██████████| 4221/4221 [01:44<00:00, 40.22it/s]
# (4221, 224, 224, 3)

# %%
# separating the target
y = train['class']

# creating the training and validation set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2, stratify = y)

# %%
# creating dummies of target variable for train and validation set
y_train = pd.get_dummies(y_train)
y_test = pd.get_dummies(y_test)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense
from keras.layers import SeparableConv2D

def create_model():
    
    def add_conv_block(model, num_filters):
        
        model.add(Conv2D(num_filters, 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(SeparableConv2D(num_filters, 3, activation='relu', padding='valid'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.2))

        return model
    
    model = tf.keras.models.Sequential()
    model.add(Input(shape=(224, 224, 3)))
    
    model = add_conv_block(model, 32)
    model = add_conv_block(model, 64)
    model = add_conv_block(model, 128)
    model = add_conv_block(model, 256)
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 32)      128
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 222, 222, 32)      1344
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 111, 111, 64)      18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 111, 111, 64)      256
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 109, 109, 64)      4736
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 54, 54, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 54, 54, 128)       512
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 52, 52, 128)       17664
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 26, 26, 256)       1024
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 24, 24, 256)       68096
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 12, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               9437440
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 9,952,770
# Trainable params: 9,951,810
# Non-trainable params: 960
# _________________________________________________________________

# %%
# %%time
h = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=200, batch_size=128
    )
# Out:
# Epoch 1/200
#  2/27 [=>............................] - ETA: 14s - loss: 0.9850 - accuracy: 0.5234WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1332s vs `on_train_batch_end` time: 1.0118s). Check your callbacks.
# 27/27 [==============================] - 34s 1s/step - loss: 0.8121 - accuracy: 0.5732 - val_loss: 0.6915 - val_accuracy: 0.5408
# Epoch 2/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.5398 - accuracy: 0.7174 - val_loss: 0.6899 - val_accuracy: 0.5408
# Epoch 3/200
# 27/27 [==============================] - 35s 1s/step - loss: 0.2866 - accuracy: 0.8744 - val_loss: 0.7452 - val_accuracy: 0.5408
# Epoch 4/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.1499 - accuracy: 0.9405 - val_loss: 1.1429 - val_accuracy: 0.5408
# Epoch 5/200
# 27/27 [==============================] - 35s 1s/step - loss: 0.0928 - accuracy: 0.9695 - val_loss: 1.8331 - val_accuracy: 0.5408
# Epoch 6/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0757 - accuracy: 0.9754 - val_loss: 2.4453 - val_accuracy: 0.5408
# Epoch 7/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0439 - accuracy: 0.9852 - val_loss: 4.5418 - val_accuracy: 0.5408
# Epoch 8/200
# 27/27 [==============================] - 33s 1s/step - loss: 0.0354 - accuracy: 0.9884 - val_loss: 3.5315 - val_accuracy: 0.5408
# Epoch 9/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0392 - accuracy: 0.9876 - val_loss: 4.6855 - val_accuracy: 0.5408
# Epoch 10/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 5.5796 - val_accuracy: 0.5408
# Epoch 11/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0195 - accuracy: 0.9941 - val_loss: 6.5772 - val_accuracy: 0.5408
# Epoch 12/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0144 - accuracy: 0.9944 - val_loss: 8.0150 - val_accuracy: 0.5408
# Epoch 13/200
# 27/27 [==============================] - 35s 1s/step - loss: 0.0281 - accuracy: 0.9917 - val_loss: 7.4325 - val_accuracy: 0.5408
# Epoch 14/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0224 - accuracy: 0.9911 - val_loss: 8.0439 - val_accuracy: 0.5408
# Epoch 15/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0095 - accuracy: 0.9964 - val_loss: 7.5410 - val_accuracy: 0.5408
# Epoch 16/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0151 - accuracy: 0.9950 - val_loss: 6.2255 - val_accuracy: 0.5408
# Epoch 17/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 4.4270 - val_accuracy: 0.5408
# Epoch 18/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 3.7993 - val_accuracy: 0.5444
# Epoch 19/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0123 - accuracy: 0.9950 - val_loss: 2.8724 - val_accuracy: 0.5491
# Epoch 20/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 1.7055 - val_accuracy: 0.6935
# Epoch 21/200
# 27/27 [==============================] - 33s 1s/step - loss: 0.0119 - accuracy: 0.9970 - val_loss: 0.2834 - val_accuracy: 0.8840
# Epoch 22/200
# 27/27 [==============================] - 33s 1s/step - loss: 0.0159 - accuracy: 0.9961 - val_loss: 0.0256 - val_accuracy: 0.9929
# Epoch 23/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0465 - val_accuracy: 0.9822
# Epoch 24/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.1253 - val_accuracy: 0.9562
# Epoch 25/200
# 27/27 [==============================] - 33s 1s/step - loss: 0.
- accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9976
# Epoch 150/200
# 27/27 [==============================] - 34s 1s/step - loss: 2.3263e-04 - accuracy: 0.9997 - val_loss: 0.0359 - val_accuracy: 0.9953
# Epoch 151/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 1.0823 - val_accuracy: 0.9053
# Epoch 152/200
# 27/27 [==============================] - 35s 1s/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0211 - val_accuracy: 0.9976
# Epoch 153/200
# 27/27 [==============================] - 35s 1s/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0227 - val_accuracy: 0.9976
# Epoch 154/200
# 27/27 [==============================] - 35s 1s/step - loss: 2.5370e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9964
# Epoch 155/200
# 27/27 [==============================] - 35s 1s/step - loss: 2.3994e-04 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9976
# Epoch 156/200
# 27/27 [==============================] - 35s 1s/step - loss: 4.8141e-04 - accuracy: 0.9997 - val_loss: 0.0151 - val_accuracy: 0.9988
# Epoch 157/200
# 27/27 [==============================] - 33s 1s/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0208 - val_accuracy: 0.9953
# Epoch 158/200
# 27/27 [==============================] - 33s 1s/step - loss: 2.9707e-04 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9964
# Epoch 159/200
# 27/27 [==============================] - 34s 1s/step - loss: 8.8539e-04 - accuracy: 0.9994 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 160/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0089 - accuracy: 0.9979 - val_loss: 0.0382 - val_accuracy: 0.9964
# Epoch 161/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0069 - accuracy: 0.9988 - val_loss: 0.1101 - val_accuracy: 0.9834
# Epoch 162/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.1645 - val_accuracy: 0.9680
# Epoch 163/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.0132 - val_accuracy: 0.9964
# Epoch 164/200
# 27/27 [==============================] - 35s 1s/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0249 - val_accuracy: 0.9953
# Epoch 165/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0112 - accuracy: 0.9985 - val_loss: 0.0071 - val_accuracy: 0.9976
# Epoch 166/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0064 - val_accuracy: 0.9976
# Epoch 167/200
# 27/27 [==============================] - 35s 1s/step - loss: 3.8275e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9988
# Epoch 168/200
# 27/27 [==============================] - 35s 1s/step - loss: 1.4046e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9988
# Epoch 169/200
# 27/27 [==============================] - 34s 1s/step - loss: 1.3952e-04 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9988
# Epoch 170/200
# 27/27 [==============================] - 34s 1s/step - loss: 1.0616e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9988
# Epoch 171/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0098 - val_accuracy: 0.9976
# Epoch 172/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0010 - accuracy: 0.9994 - val_loss: 0.0304 - val_accuracy: 0.9953
# Epoch 173/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0161 - val_accuracy: 0.9988
# Epoch 174/200
# 27/27 [==============================] - 34s 1s/step - loss: 8.5521e-05 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9988
# Epoch 175/200
# 27/27 [==============================] - 34s 1s/step - loss: 1.4705e-04 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9988
# Epoch 176/200
# 27/27 [==============================] - 35s 1s/step - loss: 1.1724e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9988
# Epoch 177/200
# 27/27 [==============================] - 35s 1s/step - loss: 6.2314e-05 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9988
# Epoch 178/200
# 27/27 [==============================] - 34s 1s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0148 - val_accuracy: 0.9988
# Epoch 179/200
# 27/27 [==============================] - 34s 1s/step - loss: 3.3561e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9988
# Epoch 180/200
# 27/27 [==============================] - 34s 1s/step - loss: 2.5546e-05 - accuracy: 1.0000 - val_loss: 4.1441e-04 - val_accuracy: 1.0000
# Epoch 181/200
# 27/27 [==============================] - 34s 1s/step - loss: 4.1810e-04 - accuracy: 0.9997 - val_loss: 0.0117 - val_accuracy: 0.9988
# Epoch 182/200
# 27/27 [==============================] - 34s 1s/step - loss: 1.0839e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9988
# Epoch 183/200
# 27/27 [==============================] - 34s 1s/step - loss: 1.7947e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9988
# Epoch 184/200
# 27/27 [==============================] - 35s 1s/step - loss: 7.0750e-05 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9988
# Epoch 185/200
# 27/27 [==============================] - 35s 1s/step - loss: 7.7425e-05 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9988
# Epoch 186/200
# 27/27 [==============================] - 35s 1s/step - loss: 2.6629e-05 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9988
# Epoch 187/200
# 27/27 [==============================] - 34s 1s/step - loss: 2.8368e-04 - accuracy: 0.9997 - val_loss: 0.0132 - val_accuracy: 0.9988
# Epoch 188/200
# 27/27 [==============================] - 34s 1s/step - loss: 9.8721e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9988
# Epoch 189/200
# 27/27 [==============================] - 34s 1s/step - loss: 7.2750e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9988
# Epoch 190/200
# 27/27 [==============================] - 34s 1s/step - loss: 5.5290e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9988
# Epoch 191/200
# 27/27 [==============================] - 35s 1s/step - loss: 4.3954e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9988
# Epoch 192/200
# 27/27 [==============================] - 35s 1s/step - loss: 8.1850e-06 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9988
# Epoch 193/200
# 27/27 [==============================] - 34s 1s/step - loss: 3.1253e-05 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9988
# Epoch 194/200
# 27/27 [==============================] - 34s 1s/step - loss: 2.1302e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9988
# Epoch 195/200
# 27/27 [==============================] - 34s 1s/step - loss: 2.1353e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9988
# Epoch 196/200
# 27/27 [==============================] - 34s 1s/step - loss: 1.0557e-05 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9988
# Epoch 197/200
# 27/27 [==============================] - 34s 1s/step - loss: 9.0602e-06 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9988
# Epoch 198/200
# 27/27 [==============================] - 35s 1s/step - loss: 2.0153e-04 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9976
# Epoch 199/200
# 27/27 [==============================] - 35s 1s/step - loss: 2.4916e-04 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9988
# Epoch 200/200
# 27/27 [==============================] - 35s 1s/step - loss: 3.0558e-05 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9988
# CPU times: user 1h 11min 41s, sys: 36min 41s, total: 1h 48min 23s
# Wall time: 1h 54min 16s

# %%
# getting the test list
f = open("test.txt", "r")
temp = f.read()
videos = temp.split('\n')

# creating the dataframe
test = pd.DataFrame()
test['video_name'] = videos
test = test[:-1]
test_videos = test['video_name']
test.head()
# Out:
#                       video_name
# 0   Harassment/Harassment_h7.mp4
# 1  Harassment/Harassment_h11.mp4
# 2  Harassment/Harassment_h16.mp4
# 3  Harassment/Harassment_h20.mp4
# 4  Harassment/Harassment_h23.mp4

# %%
# creating the tags
train = pd.read_csv('Data/train_new.csv')
y = train['class']
y = pd.get_dummies(y)

# %%
from glob import glob
from scipy import stats as s
# creating two lists to store predicted and actual tags
predict = []
actual = []

# for loop to extract frames from each test video
for i in tqdm(range(test_videos.shape[0])):
    count = 0
    videoFile = test_videos[i]
    cap = cv2.VideoCapture('Data/'+videoFile)   # capturing the video from the given path
    frameRate = cap.get(5) #frame rate
    x=1
    # removing all other files from the temp folder
    files = glob('temp/*')
    for f in files:
        os.remove(f)
    while(cap.isOpened()):
        frameId = cap.get(1) #current frame number
        ret, frame = cap.read()
        if (ret != True):
            break
        if (frameId % 3 == 0):
            # storing the frames of this particular video in temp folder
            filename ='temp/' + "_frame%d.jpg" % count;count+=1
            cv2.imwrite(filename, frame)
    cap.release()
    
    # reading all the frames from temp folder
    images = glob("temp/*.jpg")
    
    prediction_images = []
    for i in range(len(images)):
        img = image.load_img(images[i], target_size=(224,224,3))
        img = image.img_to_array(img)
        img = img/255.0
        prediction_images.append(img)
        
    # converting all the frames for a test video into numpy array
    prediction_images = np.array(prediction_images)
    # extracting features using pre-trained model
    #prediction_images = model.predict(prediction_images)
    # converting features in one dimensional array
    #prediction_images = prediction_images.reshape(prediction_images.shape[0], 7*7*512)
    # predicting tags for each array
    prediction = model.predict_classes(prediction_images)
    # appending the mode of predictions in predict list to assign the tag to the video
    predict.append(y.columns.values[s.mode(prediction)[0][0]])
    # appending the actual tag of the video
    if (videoFile.split('/')[1].split('_')[0] == 'Harassment'):
        actual.append(1)
    else:
        actual.append(0)
    # actual.append(videoFile.split('/')[1].split('_')[1])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# WARNING:tensorflow:From <ipython-input-11-d7af842e2a1c>:46: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 100%|██████████| 20/20 [01:21<00:00,  4.09s/it]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predict, actual)*100
# Out:
# 95.0
